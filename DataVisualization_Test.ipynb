# %%
# %config Completer.use_jedi = False

# %%
#데이터 분석 및 시각화 라이브러리
import matplotlib as mpl
import matplotlib.pyplot as plt
print("matplotlib version: {}". format(mpl.__version__))

import seaborn as sns
print("seaborn version: {}". format(sns.__version__))

#seaborn 스타일 설정
sns.set_style('whitegrid')

import pandas as pd
print("pandas version: {}". format(pd.__version__))

import numpy as np
print("numpy version: {}". format(np.__version__))

#기타 라이브러리
import os
import random
import time

#경고 에러 무시
import warnings
warnings.filterwarnings('ignore')
print('-'*50)
# Out:
# matplotlib version: 3.4.3
# seaborn version: 0.11.2
# pandas version: 1.3.4
# numpy version: 1.20.3
# --------------------------------------------------

# %% [markdown]
# ### 1. 시각화의 시대

# %%
#엔스콤 데이터는 seaborn 라이브러리에 내장 되어 있음 

#엔스콤 데이터셋 로드 
ans = sns.load_dataset('anscombe')

#데이터 확인
ans
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %%
ans.dtypes
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %%
ans.describe()
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %%
ans.groupby(['dataset']).describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
import matplotlib.pyplot as plt
data1=ans[ans['dataset']== 'I']
data1
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68

# %%
plt.plot(data1['x'],data1['y'] )

# %%
plt.plot(data1['x'],data1['y'],'o' )

# %%
data2=ans[ans['dataset']== 'II']
data3=ans[ans['dataset']== 'III']
data4=ans[ans['dataset']== 'IV']

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
fig

# %%
ax1.set_title('data1')
ax1.plot(data1['x'],data1['y'],'o' )
ax2.set_title('data2')
ax2.plot(data2['x'],data2['y'],'o' )
ax3.set_title('data3')
ax3.plot(data3['x'],data3['y'],'o' )
ax4.set_title('data4')
ax4.plot(data4['x'],data4['y'],'o' )
fig

# %% [markdown]
# ### 2. 기본시각화

# %%
#간단한 시작
plt.plot([1, 2, 3, 4])

# %% [markdown]
# #### 시각화 옵션- 제목/범례/색상/축이름

# %%
# 제목추가
import matplotlib.pyplot as plt
plt.title('Line')
plt.plot([1,2,3], [1,2,3], marker='s')
plt.show()

# %%
# 범례추가
plt.title('Legend')
plt.plot([1,2,3,4], label='asc') # 증가 
plt.plot([4,3,2,1], label='desc') # 감소
plt.legend()
plt.show()

# %%
# 색상
plt.plot([1,2,3], [1,2,3], color='red')
plt.show()

# %%
# 축이름
plt.plot([1,2,3], [1,2,3])
plt.xlabel("X")
plt.ylabel("Y Line")
plt.show()

# %%
# 선모양 변경
plt.plot([1,2,3,4], color='r', linestyle='--', label='dashed') # 빨간색 
plt.plot([4,3,2,1], color='g', linestyle=':', label='dotted') # 감소
plt.legend()
plt.show()

# %%
# 그림 범위
plt.title("x, y 레인지")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %% [markdown]
# #### 한글폰트사용

# %%
#matplotlib 패키지 한글 폰트 설정 시작
#윈도우
plt.rc('font', family='NanumGothic')

# %%
# 그림 범위
plt.title("x, y 레인지")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.xlim(0, 50)
plt.ylim(-10, 30)
plt.show()

# %% [markdown]
# #### 일차시각화

# %%
#데이터 준비 
titanic = sns.load_dataset("titanic")    # 타이타닉 데이터

#데이터 보기

titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
#기본 선
titanic.plot()  
titanic.plot(kind='line')
 
#히스토그램
titanic.plot(kind='hist')
 
#박스플롯
titanic.plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 선그래프

# %%
#선 그래프
plt.plot(titanic.age)

# %% [markdown]
# #### 막대그래프

# %%
#X축 범주형, Y축 연속형
plt.bar(titanic.sex,titanic.age)
# Out:
# <BarContainer object of 891 artists>

# %% [markdown]
# #### 산점도

# %%
#X축 연속형, Y축 연속형
plt.scatter(titanic.age, titanic.fare)

# %% [markdown]
# #### 히스토그램

# %%
#X축 변수, Y축 빈도
plt.hist(titanic.age)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(titanic.fare)
# Out:
# (array([732., 106.,  31.,   2.,  11.,   6.,   0.,   0.,   0.,   3.]),
#  array([  0.     ,  51.23292, 102.46584, 153.69876, 204.93168, 256.1646 ,
#         307.39752, 358.63044, 409.86336, 461.09628, 512.3292 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### 3. 고급시각화

# %% [markdown]
# #### 배경설정

# %%
#한글타이틀
plt.rc('font', family='NanumGothic') 

#데이터 준비 
tips = sns.load_dataset("tips")    # 팁 데이터
flights = sns.load_dataset("flights")    # 여객운송 데이터

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#기본 배경 설정
sns.set_palette("pastel")

#시각화
sns.stripplot(x="day", y="total_bill", data=tips)

# 개인화
plt.title('팁데이터')
plt.ylabel("요금")
plt.xlabel("요일")
# Out:
# Text(0.5, 0, '요일')

# %% [markdown]
# #### 막대그래프

# %%
#평균치 빠르게 집계해서 시각화하기
sns.barplot(x= "sex",y= "tip",data= tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
#여러 열에서 집단 묶어서 세부 집단 시각화 하기 
# hue 파라미터 추가
sns.barplot(x= "sex",y= "tip",hue="day", data= tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %% [markdown]
# #### 박스플롯

# %%
sns.boxplot(x= "sex",y= "tip",data= tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(data= tips, orient="h")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 박스플롯으로 이상치 제거 시각화

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(data=tips)
# Out:
# <AxesSubplot:>

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
(tips['total_bill'] < 40) & (tips["tip"] < 8)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Length: 244, dtype: bool

# %%
newtips = tips[(tips['total_bill'] < 40) & (tips["tip"] < 8)]
newtips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [234 rows x 7 columns]

# %%
sns.boxplot(data=newtips)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4. 변수 유형별 시각화

# %% [markdown]
# #### 일변수

# %% [markdown]
# #### 연속형

# %%
# plt.hist(x=dataset.total_bill, bins=10, density=True) #확률
plt.hist(x=newtips.total_bill, bins=10, density=False) #빈도수
plt.title('Histogram about total_bill')
plt.show()

# %%
#커널 밀도 추정(Kernel Density Estimator, KDE)함수를 적용하여, 히스토그램을 부드러운 형태의 곡선을로써 보여주는 방법 
#sns.kdeplot(데이터프레임.변수)
sns.kdeplot(data=newtips.total_bill.values, shade=True) 
plt.title('KDC about total_bill')
plt.show()

# %%
#히스토그램과 커널 밀도 곡선, 러그 플롯을 동시에 표현
sns.distplot(a=newtips.total_bill.values, kde=True, rug=True)
plt.title('distplot about total_bill')
plt.show()

# %% [markdown]
# #### 범주형

# %%
#countplot(x="변수", data=데이터프레임)
sns.countplot(x="day", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
#sns.catplot(x='day', kind='count', data=데이터프레임)
sns.catplot(x='day', kind='count', data=tips)

# %%
plt.pie(newtips.day.value_counts().values, labels=newtips.day.value_counts().index.values)
plt.title('Pie Chart about day')
plt.show()

# %% [markdown]
# #### 이변수

# %%
#연속형/연속형

# %%
#jointplot(x="x_name", y="y_name", data=dataframe, kind='scatter')
sns.jointplot(x="total_bill", y="tip", data=tips)

# %%
#커널밀도함수
sns.jointplot(x="total_bill", y="tip", data=tips, kind="kde")

# %%
#범주형/범주형

# %%
tips_var= tips.pivot_table(index="smoker", columns="sex", aggfunc="size")
tips_var
sns.heatmap(tips_var, cmap=sns.light_palette("gray", as_cmap=True), annot=True, fmt="d")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='smoker'>

# %%
#범주형/연속형
sns.catplot(x="day", y="total_bill", hue="sex", kind="swarm", data=tips)

# %%
sns.violinplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #### 다변량

# %% [markdown]
# #### 다변량 연속형

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue="sex")

# %% [markdown]
# #### 다변량 범주형

# %%
# catplot
sns.catplot(x="day",y="total_bill",hue="smoker",col="time", aspect=.6, kind="swarm", data=tips)

# %%
# boxplot
sns.boxplot(x="day", y="total_bill", hue="sex", data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# stripplot
sns.stripplot(x="day", y="total_bill", hue="sex", data=tips, jitter=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
# violinplot
sns.violinplot(x="day", y="total_bill", hue="sex", data=tips, split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #### 다차원그래프

# %%
sns.boxplot(x="tip", y="day", data=tips, whis=np.inf)
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
sns.stripplot(x="tip", y="day", data=tips, jitter=True, color="0.4")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='day'>

# %%
# violinplot과 swarmplot의 다차원그래프
sns.violinplot(x="day", y="total_bill", data=tips, inner=None)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day", y="total_bill", data=tips, color="0.9")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#히트맵
#데이터 준비
flights = sns.load_dataset("flights")    # 여객운송 데이터

# %%
print(flights); print('-'*50)
print(flights.info()); print('-'*50)
print(flights.describe()); print('-'*50)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB
# None
# --------------------------------------------------
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000
# --------------------------------------------------

# %%
#히트맵을 구성하기 앞서 필요한 특성으로 피봇 테이블을 만들어줍니다.
pivot_table = flights.pivot(index='month', columns='year', values='passengers')
pivot_table.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
plt.figure(figsize=(10,8))
sns.heatmap(pivot_table, annot=True, fmt='d')
plt.show()

# %% [markdown]
# ### 인터렉티브 데이터 시각화: 보케

# %%
import bokeh.sampledata

# %%
# Standard imports 

from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# Plot a complex chart with intearctive hover in a few lines of code

from bokeh.models import ColumnDataSource, HoverTool
from bokeh.plotting import figure
from bokeh.sampledata.autompg import autompg_clean as df
from bokeh.transform import factor_cmap

df.cyl = df.cyl.astype(str)
df.yr = df.yr.astype(str)

group = df.groupby(by=['cyl', 'mfr'])
source = ColumnDataSource(group)

p = figure(plot_width=800, plot_height=300, title="Mean MPG by # Cylinders and Manufacturer",
           x_range=group, toolbar_location=None, tools="")

p.xgrid.grid_line_color = None
p.xaxis.axis_label = "Manufacturer grouped by # Cylinders"
p.xaxis.major_label_orientation = 1.2

index_cmap = factor_cmap('cyl_mfr', palette=['#2b83ba', '#abdda4', '#ffffbf', '#fdae61', '#d7191c'], 
                         factors=sorted(df.cyl.unique()), end=1)

p.vbar(x='cyl_mfr', top='mpg_mean', width=1, source=source,
       line_color="white", fill_color=index_cmap, 
       hover_line_color="darkgrey", hover_fill_color=index_cmap)

p.add_tools(HoverTool(tooltips=[("MPG", "@mpg_mean"), ("Cyl, Mfr", "@cyl_mfr")]))

show(p)
# Out:
#   <div class="bk-root" id="36a3c9d4-38a1-4d0a-b822-e91cdfdb0411" data-root-id="1004"></div>

# %%
# Create and deploy interactive data applications

from IPython.display import IFrame 
IFrame('https://demo.bokeh.org/sliders', width=900, height=500)
# Out:
#         <iframe
#             width="900"
#             height="500"
#             src="https://demo.bokeh.org/sliders"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 시계열 시각화 실습

# %%
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

#판다스 라이브러리 불러오기
import pandas as pd 
#파일경로를 찾고 변수 file_path에 저장
file_path= 'time_series.csv'
#read csv()함수로 데이터프레임 변환 
df= pd.read_csv(file_path)

print(df)
# 현재 날짜를 나타내는 Date컬럼은 문자형(object)이므로 to_datetime()함수를 이용해서 
# Date컬럼을 시계열 객체(Timestamp)로 변환
df.info()
# Out:
#            date      value
# 0    2006-07-22   3.526591
# 1    2006-08-22   3.180891
# 2    2006-09-22   3.252221
# 3    2006-10-22   3.611003
# 4    2006-11-22   3.565869
# ..          ...        ...
# 199  2023-02-22  21.654285
# 200  2023-03-23  18.264945
# 201  2023-04-23  23.107677
# 202  2023-05-23  22.912510
# 203  2023-06-23  19.431740
#
# [204 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    204 non-null    object
#  1   value   204 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.3+ KB

# %%
df['new_date'] = pd.to_datetime(df['date'])
print(df.head())
print('\n')
# Out:
#          date     value   new_date
# 0  2006-07-22  3.526591 2006-07-22
# 1  2006-08-22  3.180891 2006-08-22
# 2  2006-09-22  3.252221 2006-09-22
# 3  2006-10-22  3.611003 2006-10-22
# 4  2006-11-22  3.565869 2006-11-22

# %%
print(df.info())
print('\n')
print(type(df['new_date'][0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      204 non-null    object
#  1   value     204 non-null    float64
#  2   new_date  204 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 4.9+ KB
# None
#
#
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
df.drop('date', axis = 1, inplace=True)
df.set_index('new_date', inplace=True)
print(df.head())
print('\n')
print(df.info())
# Out:
#                value
# new_date
# 2006-07-22  3.526591
# 2006-08-22  3.180891
# 2006-09-22  3.252221
# 2006-10-22  3.611003
# 2006-11-22  3.565869
#
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 204 entries, 2006-07-22 to 2023-06-23
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   value   204 non-null    float64
# dtypes: float64(1)
# memory usage: 3.2 KB
# None

# %%
from dateutil.parser import parse 
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
plt.rcParams.update({'figure.figsize': (10, 7), 'figure.dpi': 120})

# Draw Plot
def plot_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()

plot_df(df, x=df.index, y=df.value, title='Time series data')

# %%
df
# Out:
#                 value
# new_date
# 2006-07-22   3.526591
# 2006-08-22   3.180891
# 2006-09-22   3.252221
# 2006-10-22   3.611003
# 2006-11-22   3.565869
# ...               ...
# 2023-02-22  21.654285
# 2023-03-23  18.264945
# 2023-04-23  23.107677
# 2023-05-23  22.912510
# 2023-06-23  19.431740
#
# [204 rows x 1 columns]

# %%
# Import Data
df = pd.read_csv('time_series.csv', parse_dates=['date'], index_col='date')
df.reset_index(inplace=True)

# Prepare data
df['year'] = [d.year for d in df.date ]
df['month'] = [d.strftime('%b') for d in df.date ]
years = df['year'].unique()

# Prep Colors
np.random.seed(100)
mycolors = np.random.choice(list(mpl.colors.XKCD_COLORS.keys()), len(years), replace=False)

# Draw Plot
plt.figure(figsize=(16,12), dpi= 80)
for i, y in enumerate(years):
    if i > 0:        
        plt.plot('month', 'value', data=df.loc[df.year==y, :], color=mycolors[i], label=y)
        plt.text(df.loc[df.year==y, :].shape[0]-.9, df.loc[df.year==y, 'value'][-1:].values[0], y, fontsize=12, color=mycolors[i])

# Decoration
plt.gca().set(xlim=(-0.3, 11), ylim=(2, 30), ylabel='$Drug Sales$', xlabel='$Month$')
plt.yticks(fontsize=12, alpha=.7)
plt.title("Time series data", fontsize=20)
plt.show()

# %%
# Import Data
df = pd.read_csv('time_series.csv', parse_dates=['date'], index_col='date')
df.reset_index(inplace=True)

# Prepare data
df['year'] = [d.year for d in df.date]
df['month'] = [d.strftime('%b') for d in df.date]
years = df['year'].unique()

# Draw Plot
fig, axes = plt.subplots(1, 2, figsize=(20,7), dpi= 80)
sns.boxplot(x='year', y='value', data=df, ax=axes[0])
sns.boxplot(x='month', y='value', data=df.loc[~df.year.isin([2006, 2023]), :])

# Set Title
axes[0].set_title('Year-wise Box Plot\n(The Trend)', fontsize=18); 
axes[1].set_title('Month-wise Box Plot\n(The Seasonality)', fontsize=18)
plt.show()

# %%
# Import Data
df = pd.read_csv('time_series.csv', parse_dates=['date'], index_col='date')
def plot_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
plot_df(df, x=df.index, y=df.value)

# %%
np.random.seed(0)
df1 = pd.DataFrame(np.random.randn(100, 3),
                   index=pd.date_range('1/1/2018', periods=100),
                   columns=['A', 'B', 'C']).cumsum()
df1.head()
# Out:
#                    A         B         C
# 2018-01-01  1.764052  0.400157  0.978738
# 2018-01-02  4.004946  2.267715  0.001460
# 2018-01-03  4.955034  2.116358 -0.101759
# 2018-01-04  5.365632  2.260402  1.352515
# 2018-01-05  6.126670  2.382077  1.796378

# %%
plt.plot(df1)
plt.show()

# %%
cospi = pd.read_csv("cospi.csv")
cospi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    249 non-null    object
#  1   Open    249 non-null    int64
#  2   High    249 non-null    int64
#  3   Low     249 non-null    int64
#  4   Close   249 non-null    int64
#  5   Volume  249 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 11.8+ KB

# %%
cospi.head()
# Out:
#          Date   Open   High    Low  Close    Volume
# 0  2023-06-02  71700  72200  71600  72200  12161798
# 1  2023-06-01  70900  71600  70600  70900  14669296
# 2  2023-05-31  72400  72500  71000  71400  25666087
# 3  2023-05-30  71300  72300  71200  72300  27476897
# 4  2023-05-26  69800  70400  69500  70300  19549511

# %%
from datetime import datetime
import pandas as pd   # csv file read
import matplotlib.pyplot as plt   # 시계열 시각화

# %%
date = cospi['Date']
len(date)
# Out:
# 249

# %%
newcospi = cospi.set_index('Date')

# %%
newcospi.head()
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2023-06-02  71700  72200  71600  72200  12161798
# 2023-06-01  70900  71600  70600  70900  14669296
# 2023-05-31  72400  72500  71000  71400  25666087
# 2023-05-30  71300  72300  71200  72300  27476897
# 2023-05-26  69800  70400  69500  70300  19549511

# %%
newcospi_HL = newcospi[['High', 'Low']]
newcospi_HL
# Out:
#              High    Low
# Date
# 2023-06-02  72200  71600
# 2023-06-01  71600  70600
# 2023-05-31  72500  71000
# 2023-05-30  72300  71200
# 2023-05-26  70400  69500
# ...           ...    ...
# 2022-06-09  65200  64500
# 2022-06-08  65700  65300
# 2022-06-07  66400  65400
# 2022-06-03  67300  66800
# 2022-06-02  67000  66400
#
# [249 rows x 2 columns]

# %%
newcospi_HL.plot(title='High')
# Out:
# <AxesSubplot:title={'center':'High'}, xlabel='Date'>
